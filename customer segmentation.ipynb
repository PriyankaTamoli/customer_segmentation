# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA

# %%
df=pd.read_csv("Mall_Customers.csv")

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.describe(include='all').T
# Out:
#                         count unique     top freq   mean        std   min  \
# CustomerID              200.0    NaN     NaN  NaN  100.5  57.879185   1.0
# Genre                     200      2  Female  112    NaN        NaN   NaN
# Age                     200.0    NaN     NaN  NaN  38.85  13.969007  18.0
# Annual Income (k$)      200.0    NaN     NaN  NaN  60.56  26.264721  15.0
# Spending Score (1-100)  200.0    NaN     NaN  NaN   50.2  25.823522   1.0
#
#                           25%    50%     75%    max
# CustomerID              50.75  100.5  150.25  200.0
# Genre                     NaN    NaN     NaN    NaN
# Age                     28.75   36.0    49.0   70.0
# Annual Income (k$)       41.5   61.5    78.0  137.0
# Spending Score (1-100)  34.75   50.0    73.0   99.0

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
X=df.iloc[:,[3,4]].values

# %%
X
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import KMeans

# %%
wss=[]
for i in range (1,10):
    kmeans=KMeans(n_clusters=i,init='k-means++',random_state=0)
    kmeans.fit(X)
    wss.append(kmeans.inertia_)
    
    
plt.plot(range(1,10),wss)
plt.show()

# %%
kmeansmodel=KMeans(n_clusters=5,init='k-means++',random_state=0)

# %%
y_means = kmeansmodel.fit_predict(X)

# %%
plt.scatter(X[y_means ==0,0], X[y_means==0,1],s=80,c="red",label='Customer1')
plt.scatter(X[y_means ==1,0], X[y_means==1,1],s=80,c="blue",label='Customer2')
plt.scatter(X[y_means ==2,0], X[y_means==2,1],s=80,c="yellow",label='Customer3')
plt.scatter(X[y_means ==3,0], X[y_means==3,1],s=80,c="cyan",label='Customer4')
plt.scatter(X[y_means ==4,0], X[y_means==4,1],s=80,c="black",label='Customer5')
plt.title('clusters of customers')
plt.xlabel('annual income')
plt.ylabel('spending score')
plt.show()
